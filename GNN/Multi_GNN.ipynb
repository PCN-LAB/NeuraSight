# %% [markdown]
# ### Install Miniconda for Linux x86_64 architecture

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda -y
# Out:
# --2024-07-16 09:26:33--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146836934 (140M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 140.03M   135MB/s    in 1.0s
#
# 2024-07-16 09:26:35 (135 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [146836934/146836934]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %% [markdown]
# ### Clone Repo and Install Conda Environment

# %%
# Clone the Multi-GNN repository from GitHub
# !git clone https://github.com/codebyahmed/Multi-GNN
# %cd "/content/Multi-GNN"
# Out:
# Cloning into 'Multi-GNN'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 97 (delta 34), reused 28 (delta 25), pack-reused 49
# Receiving objects: 100% (97/97), 82.39 MiB | 49.86 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/Multi-GNN

# %%
# Create a new Conda environment from the env.yml file
# %%shell
eval "$(conda shell.bash hook)"
conda env create -f env.yml
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | :  45% 0.44728820847907824/1 [00:25<00:02,  5.26s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :  94% 0.9366234694119104/1 [00:25<00:01, 19.38s/it]
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | :  30% 0.3038880565368677/1 [00:25<00:10, 15.18s/it]
#
#
#
#
#
#
# pytorch-2.2.0        | 1.52 GB   | :  42% 0.4194531611028135/1 [00:25<00:27, 47.23s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :  94% 0.9431486274158313/1 [00:25<00:01, 18.05s/it]
#
#
#
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | :  50% 0.5044027987007218/1 [00:25<00:02,  4.61s/it]
#
#
#
#
#
#
#
# pytorch-2.2.0        | 1.52 GB   | :  42% 0.42162155214218855/1 [00:25<00:28, 48.46s/it]
# cudatoolkit-11.8.0   | 682.5 MB  | :  95% 0.9487579737700789/1 [00:25<00:00, 19.22s/it]
#
#
#
#
#
#
# pytorch-2.2.0        | 1.52 GB   | :  42% 0.423719671249732/1 [00:25<00:28, 49.61s/it]
#
#
#
#
#
#
#
# ...

# %%
# %env PYTHONPATH = #/env/python

# Add the site-packages directories to the Python path
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')
sys.path.append('/usr/local/envs/multignn/lib/python3.9/site-packages')
# Out:
# env: PYTHONPATH=#/env/python

# %% [markdown]
# ### Add and Update Data Config file with proper paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
file_path = "/content/Multi-GNN/data_config.json"
with open(file_path, "r") as file:
    data = json.load(file)

data["paths"]["aml_data"] = "/content/drive/MyDrive/GNN-Data"
data["paths"]["model_to_load"] = "/content/drive/MyDrive/GNN-Model"
data["paths"]["model_to_save"] = "/content/drive/MyDrive/GNN-Model"

with open(file_path, "w") as file:
    json.dump(data, file, indent=2)

# %% [markdown]
# ### Train the Model

# %% [markdown]
# ```
# usage: main.py [-h] [--emlps] [--reverse_mp] [--ports] [--tds] [--ego] [--batch_size BATCH_SIZE]
#                [--n_epochs N_EPOCHS] [--num_neighs NUM_NEIGHS [NUM_NEIGHS ...]] [--seed SEED]
#                [--tqdm] --data DATA --model MODEL [--testing] [--save_model] [--unique_name]
#                [--finetune] [--inference]```

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate multignn
# #python main.py --data Small_HI --model gin --tqdm --n_epochs 10 --save_model --unique_name
# python main.py --data Small_HI --model gin --unique_name --emlps --reverse_mp --ego --ports --tqdm --inference
# #python main.py --data Small_HI --model gin --emlps --reverse_mp --ego --ports --tqdm --save_model --unique_name --finetune
# #python main.py --data Small_HI --model gin --tqdm --save_model --unique_name --n_epochs 10
# #python main.py --data Small_HI --model gin --tqdm --save_model --unique_name 'gin' --n_epochs 10 --finetune
# #python main.py --data Small_HI --model gin --tqdm --unique_name 'gin' --testing --inference
# #API_KEY: 6def1d725694dd6eced0b8f9c6e98eceafcad32a
# Out:
# 2024-07-16 10:30:03,436 [INFO ] Random seed set as 1
# 2024-07-16 10:30:03,437 [INFO ] Retrieving data
# 2024-07-16 10:30:08,091 [INFO ] Available Edge Features: ['EdgeID', 'from_id', 'to_id', 'Timestamp', 'Amount Sent', 'Sent Currency', 'Amount Received', 'Received Currency', 'Payment Format', 'Is Laundering']
# 2024-07-16 10:30:57,407 [INFO ] Illicit ratio = 5177 / 5078345 = 0.10%
# 2024-07-16 10:30:57,407 [INFO ] Number of nodes (holdings doing transcations) = 515088
# 2024-07-16 10:30:57,407 [INFO ] Number of transactions = 5078345
# 2024-07-16 10:30:57,407 [INFO ] Edge features being used: ['Timestamp', 'Amount Received', 'Received Currency', 'Payment Format']
# 2024-07-16 10:30:57,407 [INFO ] Node features being used: ['Feature'] ("Feature" is a placeholder feature of all 1s)
# 2024-07-16 10:30:57,541 [INFO ] number of days and transactions in the data: 18 days, 5078345 transactions
# ...
